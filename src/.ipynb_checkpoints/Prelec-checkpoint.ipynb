# %%
import numpy as np
import pandas as pd
# Study 1c: Study on 50 U.S. states. state - name of the state, city - name of the city asked
# Every state is asked with it's true capital
study_1c = pd.read_csv('~/DATA_1030/Final_Project/crowd_wisdom_data/study1c.csv')
# Study 2: Trivia. qname - the topic of the trivia question (39 participants, 80 unique qnames)
study_2 = pd.read_csv('~/DATA_1030/Final_Project/crowd_wisdom_data/study2.csv')
# Study 3: Dermatologists diagnosing lesions as malignant or benign
study_3 = pd.read_csv('~/DATA_1030/Final_Project/crowd_wisdom_data/study3.csv')

# %%
study_1c = study_1c.drop(["expt city", "subject"], axis=1)
study_2 = study_2.drop(['subject', 'qname'], axis=1)
study_3 = study_3.drop(['subject'], axis=1)

# %%
study_1c.columns = ['q', 'own', 'meta', 'confidence', "actual"]
study_2.columns = ['own', 'meta', 'q', "actual", 'confidence']
study_3.columns = ['own', 'actual', 'q', 'meta', 'confidence']
frames = [study_1c, study_2, study_3]

# %%
result = pd.concat(frames)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
result = result.groupby("q").mean()
result["prelec_prediction"] = np.where(result['meta'] > result['own'], 0,  1)
result["accuracy"] = np.where(result['prelec_prediction'] == result['actual'], 1,  0)

# %%
result = result.drop(['actual', 'confidence', 'meta', 'own', 'accuracy'], axis=1)

# %%
result.to_csv("")
# Out:
#                                            prelec_prediction
# q
# 'Cheval' is French for 'cow'                               0
# 1 - malignant nodular melanoma.jpg                         1
# 10 - Malignant melanoma 3 (SSM).jpg                        1
# 11 - Benign hemangioma.jpg                                 1
# 11 - malignant melanoma 4 (SSM).jpg                        1
# ...                                                      ...
# William Wallace lived before King Macbeth                  1
# Wisconsin                                                  0
# Wyoming                                                    1
# malignant-Melanoma-0085.jpg                                1
# malignant-SSM-5.jpg                                        1
#
# [210 rows x 1 columns]
